# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import statsmodels.api as sm
import sqlite3
from sqlite3 import Error
from functools import reduce
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# Evaluation Metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('final_df.csv')
df
# Out:
#                           fsq_id       categories_x   closed_bucket  \
# 0       4ae0c7a8f964a520638221e3  Indian Restaurant  VeryLikelyOpen
# 1       4ae0c7a8f964a520638221e3  Indian Restaurant  VeryLikelyOpen
# 2       4ae0c7a8f964a520638221e3  Indian Restaurant  VeryLikelyOpen
# 3       4ae0c7a8f964a520638221e3  Indian Restaurant  VeryLikelyOpen
# 4       4ae0c7a8f964a520638221e3  Indian Restaurant  VeryLikelyOpen
# ...                          ...                ...             ...
# 441695  584054342980db526bddd716               Café  VeryLikelyOpen
# 441696  584054342980db526bddd716               Café  VeryLikelyOpen
# 441697  584054342980db526bddd716               Café  VeryLikelyOpen
# 441698  584054342980db526bddd716               Café  VeryLikelyOpen
# 441699  584054342980db526bddd716               Café  VeryLikelyOpen
#
#         distance_x                                         location_x  \
# 0              783  1460 Gerrard St E (Coxwell Ave), Toronto ON M4...
# ...

# %%
# Data Preparation
X = df[[ 'distance_x', 'rating', 'latitude','longitude','review_count']]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441700 entries, 0 to 441699
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   distance_x    441700 non-null  int64
#  1   rating        441700 non-null  float64
#  2   latitude      441700 non-null  float64
#  3   longitude     441700 non-null  float64
#  4   review_count  441700 non-null  int64
# dtypes: float64(3), int64(2)
# memory usage: 16.8 MB

# %%
# Check for missing values
print(X.isnull().sum())
# Out:
# distance_x      0
# rating          0
# latitude        0
# longitude       0
# review_count    0
# dtype: int64

# %%
# Add a constant term for the intercept
X = sm.add_constant(X)
X.head()
# Out:
#    const  distance_x  rating  latitude  longitude  review_count
# 0    1.0         783     4.5     43.67     -79.32             7
# 1    1.0         783     4.5     43.67     -79.32             7
# 2    1.0         783     4.5     43.67     -79.32             7
# 3    1.0         783     4.5     43.67     -79.32             7
# 4    1.0         783     4.5     43.67     -79.32             2

# %%
# Target variable
y = df['number_of_bikes']
y.head()
# Out:
# 0    18
# 1    22
# 2    18
# 3    16
# 4    18
# Name: number_of_bikes, dtype: int64

# %%
# Model Specification
model = sm.OLS(y, X)
# Estimation
results = model.fit()
# Summary of Regression Results
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        number_of_bikes   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                     5268.
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):               0.00
# Time:                        20:29:48   Log-Likelihood:            -1.1623e+06
# No. Observations:              441700   AIC:                         2.325e+06
# Df Residuals:                  441694   BIC:                         2.325e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1.397e+04    136.866   -102.098      0.000   -1.42e+04   -1.37e+04
# ...

# %%
# Due to the fact that the p-value for distance_x is 1(meaning not good at all),i'll be building another model without it to see the outcome.  
# Data Preparation
X = df[['latitude','longitude']]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441700 entries, 0 to 441699
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   latitude   441700 non-null  float64
#  1   longitude  441700 non-null  float64
# dtypes: float64(2)
# memory usage: 6.7 MB

# %%
# Check for missing values
print(X.isnull().sum())
# Out:
# latitude     0
# longitude    0
# dtype: int64

# %%
# Add a constant term for the intercept
X = sm.add_constant(X)
X.head()
# Out:
#    const  latitude  longitude
# 0    1.0     43.67     -79.32
# 1    1.0     43.67     -79.32
# 2    1.0     43.67     -79.32
# 3    1.0     43.67     -79.32
# 4    1.0     43.67     -79.32

# %%
# Target variable
y = df['number_of_bikes']
y.head()
# Out:
# 0    18
# 1    22
# 2    18
# 3    16
# 4    18
# Name: number_of_bikes, dtype: int64

# %%
# Model Specification
model = sm.OLS(y, X)
# Estimation
results = model.fit()
# Summary of Regression Results
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        number_of_bikes   R-squared:                       0.056
# Model:                            OLS   Adj. R-squared:                  0.056
# Method:                 Least Squares   F-statistic:                 1.317e+04
# Date:                Mon, 18 Dec 2023   Prob (F-statistic):               0.00
# Time:                        20:30:54   Log-Likelihood:            -1.1623e+06
# No. Observations:              441700   AIC:                         2.325e+06
# Df Residuals:                  441697   BIC:                         2.325e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.397e+04    135.487   -103.137      0.000   -1.42e+04   -1.37e+04
# ...
